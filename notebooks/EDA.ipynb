# %%
# %cd ../
# Out:
# /Users/tienphat/Documents/HCMUS/Statistic_Application/covid_analysis

# %%
import os
import os.path as osp
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

ALL_DATA_DIR = 'dataset'
US_DATA_DIR = osp.join(ALL_DATA_DIR, 'usa')

# confirm_df = pd.read_csv(osp.join(US_DATA_DIR, 'time_series_covid_19_confirmed_US.csv'))
# death_df = pd.read_csv(osp.join(US_DATA_DIR, 'time_series_covid_19_deaths_US.csv'))
# recover_df = pd.read_csv(osp.join(ALL_DATA_DIR, 'time_series_covid_19_recovered.csv'))

# %%
confirm_df['Province_State'].value_counts()
# Out:
# Texas                       256
# Georgia                     161
# Virginia                    135
# Kentucky                    122
# Missouri                    118
# Kansas                      107
# Illinois                    104
# North Carolina              102
# Iowa                        101
# Tennessee                    97
# Nebraska                     95
# Indiana                      94
# Ohio                         90
# Minnesota                    89
# Michigan                     87
# Mississippi                  84
# Oklahoma                     79
# Arkansas                     77
# Wisconsin                    74
# Pennsylvania                 69
# Florida                      69
# Alabama                      69
# South Dakota                 68
# Colorado                     66
# Louisiana                    66
# New York                     64
# California                   60
# Montana                      58
# West Virginia                57
# ...

# %%
death_df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 7/5/20  7/6/20  7/7/20  7/8/20  7/9/20  7/10/20  \
# 0 -14.2710 -170.1320  ...      0       0       0       0       0        0
# 1  13.4443  144.7937  ...      5       5       5       5       5        5
# 2  15.0979  145.6739  ...      2       2       2       2       2        2
# 3  18.2208  -66.5901  ...    155     155     157     159     159      159
# 4  18.3358  -64.8963  ...      6       6       6       6       6        6
#
#    7/11/20  7/12/20  7/13/20  7/14/20
# ...

# %%
reco_df = pd.read_csv(osp.join(ALL_DATA_DIR, "all_recovered.csv"))
reco_df.head()
del reco_df

# %%
data_df = pd.read_csv(osp.join(ALL_DATA_DIR, "state_data.csv"))
data_df['Province/State'].unique()
del data_df
